# %%
import pandas as pd

# %%
data_in = pd.read_csv('/home/harshal/projects/competitions/AdventOfCode/2024/day1.in',sep='\s+',header=None)
data_in
# Out:
#          0      1
# 0    64256  78813
# 1    46941  56838
# 2    47111  50531
# 3    48819  41511
# 4    54871  96958
# ..     ...    ...
# 995  36006  86674
# 996  30914  90095
# 997  47918  11257
# 998  64417  70229
# 999  37597  78404
#
# [1000 rows x 2 columns]

# %%
left = data_in[0].sort_values(ignore_index=True)
right = data_in[1].sort_values(ignore_index=True)
#print(left,right,abs(left-right))
abs(left-right).sum()
# Out:
# 2166959

# %%
#print(left.to_frame())
#print(right.value_counts())
ans = left.to_frame().merge(right.value_counts(),left_on=left.to_frame().columns[0], right_index=True)
(ans.iloc[:,0] * ans.iloc[:,1]).sum()
# Out:
# 23741109
